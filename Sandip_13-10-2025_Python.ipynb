# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\rsant\Downloads\Crop Prediction Dataset (U).csv")

# %%
df.head()
# Out:
#    Record_ID          Crop  Crop_Year       Season  State     Area  \
# 0          1      Arecanut       1997  Whole Year   Assam  73814.0
# 1          2     Arhar/Tur       1997  Kharif       Assam   6637.0
# 2          3   Castor seed       1997  Kharif       Assam      NaN
# 3          4      Coconut        1997  Whole Year   Assam  19656.0
# 4          5  Cotton(lint)       1997  Kharif       Assam   1739.0
#
#     Production  Annual_Rainfall  Fertilizer  Pesticide     Yield  \
# 0      56708.0           2051.4  7024878.38   22882.34  0.796087
# 1       4685.0           2051.4   631643.29    2057.47  0.710435
# 2         22.0           2051.4    75755.32     246.76  0.238333
# 3  126905000.0           2051.4  1870661.52    6093.36       NaN
# 4        794.0           2051.4   165500.63     539.09  0.420909
#
#    Production_per_Area Rainfall_Category  Fertilizer_per_Area  \
# 0             0.768255              High                95.17
# ...

# %%
df.shape
# Out:
# (19689, 17)

# %%
# 1 Identify how many columns contain null values, and for each such 
# column, determine the total number of null values.
len(df.isnull().sum())
# Out:
# 17

# %%
df.isnull().sum()
# Out:
# Record_ID                 0
# Crop                      0
# Crop_Year                 0
# Season                    0
# State                     0
# Area                   1378
# Production             1378
# Annual_Rainfall         110
# Fertilizer              563
# Pesticide                 0
# Yield                  1181
# Production_per_Area    1575
# Rainfall_Category         0
# Fertilizer_per_Area       0
# Pesticide_per_Area        0
# Yield_Category            0
# Year_Group                0
# dtype: int64

# %%
# 2. Check whether the columns Area and Production contain any null 
# values. If null values are present, first examine whether these 
# columns contain outliers. If outliers exist, fill the null values using 
# an appropriate technique. Ensure that no decimal values are 
# allowed in the Area column.

# %%
df.dtypes
# Out:
# Record_ID                int64
# Crop                    object
# Crop_Year                int64
# Season                  object
# State                   object
# Area                   float64
# Production             float64
# Annual_Rainfall        float64
# Fertilizer             float64
# Pesticide              float64
# Yield                  float64
# Production_per_Area    float64
# Rainfall_Category       object
# Fertilizer_per_Area    float64
# Pesticide_per_Area     float64
# Yield_Category          object
# Year_Group              object
# dtype: object

# %%
df.describe()
# Out:
#           Record_ID     Crop_Year          Area    Production  \
# count  19689.000000  19689.000000  1.831100e+04  1.831100e+04
# mean    9845.000000   2009.127584  1.816562e+05  1.648194e+07
# std     5683.869061      6.498099  7.437564e+05  2.639108e+08
# min        1.000000   1997.000000  5.000000e-01  0.000000e+00
# 25%     4923.000000   2004.000000  1.392000e+03  1.374500e+03
# 50%     9845.000000   2010.000000  9.378000e+03  1.368400e+04
# 75%    14767.000000   2015.000000  7.537600e+04  1.220810e+05
# max    19689.000000   2020.000000  5.080810e+07  6.326000e+09
#
#        Annual_Rainfall    Fertilizer     Pesticide         Yield  \
# count     19579.000000  1.912600e+04  1.968900e+04  18508.000000
# mean       1433.913357  2.406195e+07  4.884835e+04     73.172834
# std         817.412943  9.526848e+07  2.132874e+05    837.377629
# min         301.300000  5.417000e+01  9.000000e-02      0.000000
# 25%         935.600000  1.875406e+05  3.567000e+02      0.580000
# ...

# %%
df["Area"].isnull().sum()
# Out:
# np.int64(1378)

# %%
df["Area"]=df["Area"].fillna(df["Area"].median())

# %%
df["Production"]=df["Production"].fillna(df["Production"].median())

# %%
df["Production"].dtypes
# Out:
# dtype('float64')

# %%
df["Area"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Production"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Area"]=df["Area"].astype(int)

# %%
df["Production"]=df["Production"].astype(int)

# %%
df.head()
# Out:
#    Record_ID          Crop  Crop_Year       Season  State   Area  Production  \
# 0          1      Arecanut       1997  Whole Year   Assam  73814       56708
# 1          2     Arhar/Tur       1997  Kharif       Assam   6637        4685
# 2          3   Castor seed       1997  Kharif       Assam   9378          22
# 3          4      Coconut        1997  Whole Year   Assam  19656   126905000
# 4          5  Cotton(lint)       1997  Kharif       Assam   1739         794
#
#    Annual_Rainfall  Fertilizer  Pesticide     Yield  Production_per_Area  \
# 0           2051.4  7024878.38   22882.34  0.796087             0.768255
# 1           2051.4   631643.29    2057.47  0.710435             0.705891
# 2           2051.4    75755.32     246.76  0.238333             0.027638
# 3           2051.4  1870661.52    6093.36       NaN          6456.298331
# 4           2051.4   165500.63     539.09  0.420909             0.456584
#
# ...

# %%
# 3.  It has been observed that the missing values in the 
# Annual_Rainfall column follow an average rainfall pattern. Fill 
# the missing values using the average rainfall of the column. 
# Ensure that the final values are stored as integers (no decimal 
# values allowed).

# %%
df["Annual_Rainfall"].isnull().sum()
# Out:
# np.int64(110)

# %%
df["Annual_Rainfall"]=df["Annual_Rainfall"].fillna(df["Annual_Rainfall"].mean())

# %%
df["Annual_Rainfall"]=df["Annual_Rainfall"].astype(int)

# %%
# 4. Determine the maximum and minimum values in the Fertilizer 
# column. Calculate the average of these two values and use this 
# average to fill all missing values. Ensure that the filled values 
# contain at least two decimal places.

# %%
df.head(2)
# Out:
#    Record_ID       Crop  Crop_Year       Season  State   Area  Production  \
# 0          1   Arecanut       1997  Whole Year   Assam  73814       56708
# 1          2  Arhar/Tur       1997  Kharif       Assam   6637        4685
#
#    Annual_Rainfall  Fertilizer  Pesticide     Yield  Production_per_Area  \
# 0             2051  7024878.38   22882.34  0.796087             0.768255
# 1             2051   631643.29    2057.47  0.710435             0.705891
#
#   Rainfall_Category  Fertilizer_per_Area  Pesticide_per_Area Yield_Category  \
# 0              High                95.17                0.31            Low
# 1              High                95.17                0.31            Low
#
#   Year_Group
# 0  1997-2000
# 1  1997-2000

# %%
df["Fertilizer"].max()
# Out:
# 4835406877.0

# %%
df["Fertilizer"].min()
# Out:
# 54.17

# %%
((df["Fertilizer"].max()) +(df["Fertilizer"].min()))/2
# Out:
# 2417703465.585

# %%
df["Fertilizer"].isnull().sum()
# Out:
# np.int64(563)

# %%
df["Fertilizer"]=df["Fertilizer"].fillna(((df["Fertilizer"].max()) +(df["Fertilizer"].min()))/2)

# %%
df["Fertilizer"]=df["Fertilizer"].astype(int)

# %%
# 5. Analyze whether the Yield column contains outliers. If outliers 
# are present or not, handle the missing values using an appropriate 
# technique and justify your approach.

# %%
df.head(2)
# Out:
#    Record_ID       Crop  Crop_Year       Season  State   Area  Production  \
# 0          1   Arecanut       1997  Whole Year   Assam  73814       56708
# 1          2  Arhar/Tur       1997  Kharif       Assam   6637        4685
#
#    Annual_Rainfall  Fertilizer  Pesticide     Yield  Production_per_Area  \
# 0             2051     7024878   22882.34  0.796087             0.768255
# 1             2051      631643    2057.47  0.710435             0.705891
#
#   Rainfall_Category  Fertilizer_per_Area  Pesticide_per_Area Yield_Category  \
# 0              High                95.17                0.31            Low
# 1              High                95.17                0.31            Low
#
#   Year_Group
# 0  1997-2000
# 1  1997-2000

# %%
sns.boxplot(df["Yield"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.describe()
# Out:
#           Record_ID     Crop_Year          Area    Production  \
# count  19689.000000  19689.000000  1.968900e+04  1.968900e+04
# mean    9845.000000   2009.127584  1.695988e+05  1.532936e+07
# std     5683.869061      6.498099  7.186014e+05  2.545421e+08
# min        1.000000   1997.000000  0.000000e+00  0.000000e+00
# 25%     4923.000000   2004.000000  1.652000e+03  1.622000e+03
# 50%     9845.000000   2010.000000  9.378000e+03  1.368400e+04
# 75%    14767.000000   2015.000000  6.385400e+04  1.000000e+05
# max    19689.000000   2020.000000  5.080810e+07  6.326000e+09
#
#        Annual_Rainfall    Fertilizer     Pesticide         Yield  \
# count     19689.000000  1.968900e+04  1.968900e+04  18508.000000
# mean       1433.435218  9.250728e+07  4.884835e+04     73.172834
# std         815.127841  4.098456e+08  2.132874e+05    837.377629
# min         301.000000  5.400000e+01  9.000000e-02      0.000000
# 25%         940.000000  1.993810e+05  3.567000e+02      0.580000
# ...

# %%
df["Yield"].isnull().sum()
# Out:
# np.int64(1181)

# %%
df["Yield"]=df["Yield"].fillna(df["Yield"].median()) # there have outlier so that i use median for fill missing values

# %%
# 6. The Production_per_Area column contains missing values due to 
# data collection gaps. 
# 7. Impute the missing values in the Production_per_Area column 
# using a forward fill strategy and store the updated values back in 
# the same column.

# %%
df.head()
# Out:
#    Record_ID          Crop  Crop_Year       Season  State   Area  Production  \
# 0          1      Arecanut       1997  Whole Year   Assam  73814       56708
# 1          2     Arhar/Tur       1997  Kharif       Assam   6637        4685
# 2          3   Castor seed       1997  Kharif       Assam   9378          22
# 3          4      Coconut        1997  Whole Year   Assam  19656   126905000
# 4          5  Cotton(lint)       1997  Kharif       Assam   1739         794
#
#    Annual_Rainfall  Fertilizer  Pesticide     Yield  Production_per_Area  \
# 0             2051     7024878   22882.34  0.796087             0.768255
# 1             2051      631643    2057.47  0.710435             0.705891
# 2             2051       75755     246.76  0.238333             0.027638
# 3             2051     1870661    6093.36  0.982466          6456.298331
# 4             2051      165500     539.09  0.420909             0.456584
#
# ...

# %%
df["Production_per_Area"].isnull().sum()
# Out:
# np.int64(1575)

# %%
df["Production_per_Area"]=df["Production_per_Area"].fillna(df["Production_per_Area"].median())

# %%
df.isnull().sum()
# Out:
# Record_ID              0
# Crop                   0
# Crop_Year              0
# Season                 0
# State                  0
# Area                   0
# Production             0
# Annual_Rainfall        0
# Fertilizer             0
# Pesticide              0
# Yield                  0
# Production_per_Area    0
# Rainfall_Category      0
# Fertilizer_per_Area    0
# Pesticide_per_Area     0
# Yield_Category         0
# Year_Group             0
# dtype: int64

# %%
# 8. After completing all the data cleaning, preprocessing, and 
# transformation steps on both datasets (Crop_Production and 
# Climate_Agriculture), split the final cleaned dataset into two 
# separate CSV files and export them according to the following 
# specifications:

# %%
# Create a CSV file named Crop_ Production.csv containing only the columns:

# %%
# • Record_ID 
#• Crop_Year, 
#• Season, 
#• State,  
#• Area,  
#• Production,  
#• Yield,  
#• Production_per_Area, 
#• Yield_Category. 
#• Crop

# %%
df.head(2)
# Out:
#    Record_ID       Crop  Crop_Year       Season  State   Area  Production  \
# 0          1   Arecanut       1997  Whole Year   Assam  73814       56708
# 1          2  Arhar/Tur       1997  Kharif       Assam   6637        4685
#
#    Annual_Rainfall  Fertilizer  Pesticide     Yield  Production_per_Area  \
# 0             2051     7024878   22882.34  0.796087             0.768255
# 1             2051      631643    2057.47  0.710435             0.705891
#
#   Rainfall_Category  Fertilizer_per_Area  Pesticide_per_Area Yield_Category  \
# 0              High                95.17                0.31            Low
# 1              High                95.17                0.31            Low
#
#   Year_Group
# 0  1997-2000
# 1  1997-2000

# %%
Crop_Production = df[["Record_ID", "Crop_Year", "Season", "State", "Area","Production","Yield","Production_per_Area","Yield_Category", "Crop"]]

# %%
Crop_Production
# Out:
#        Record_ID  Crop_Year       Season              State    Area  \
# 0              1       1997  Whole Year               Assam   73814
# 1              2       1997  Kharif                   Assam    6637
# 2              3       1997  Kharif                   Assam    9378
# 3              4       1997  Whole Year               Assam   19656
# 4              5       1997  Kharif                   Assam    1739
# ...          ...        ...          ...                ...     ...
# 19684      19685       1998  Kharif                Nagaland    4000
# 19685      19686       1998  Rabi                  Nagaland    1000
# 19686      19687       1997  Kharif       Jammu and Kashmir  310883
# 19687      19688       1997  Kharif       Jammu and Kashmir  275746
# 19688      19689       1997  Rabi         Jammu and Kashmir  239344
#
#        Production     Yield  Production_per_Area Yield_Category           Crop
# ...

# %%
Crop_Production.to_csv('Crop_Production.csv', index=False)

# %%
# Create another CSV file named Climate_Agriculture.csv containing only the columns:

# %%
#• Record_ID, 
#• Annual_Rainfall,  
#• Rainfall_Category, 
#• Fertilizer, 
# • Fertilizer_per_Area,  
# • Pesticide, 
# • Pesticide_per_Area, 
# • Year_Group.

# %%
Climate_Agriculture= df[["Record_ID", "Annual_Rainfall", "Rainfall_Category", "Fertilizer", "Fertilizer_per_Area","Pesticide", "Pesticide_per_Area", "Year_Group"]]

# %%
Climate_Agriculture.to_csv('Climate_Agriculture.csv', index=False)

# %%
df.to_csv('Crop Prediction Dataset.csv', index=False)
